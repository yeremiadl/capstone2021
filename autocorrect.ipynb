# %%
import re
import string
from collections import Counter
import numpy as np

# %%
def read_corpus(filename):
  with open('words.txt', "r") as file:
    lines = file.readlines()
    words = []
    for line in lines:
      words += re.findall(r'\w+', line.lower())

  return words

# %%
words = read_corpus("words.txt")
print(f"There are {len(words)} total words in the corpus")
# Out:
# There are 515416 total words in the corpus

# %%
vocabs = set(words)
print(f"There are {len(vocabs)} unique words in the vocabulary")
# Out:
# There are 418925 unique words in the vocabulary

# %%
def my_autocorrect(input_word):
    input_word = input_word.lower()
    if input_word in V:
        return('Your word seems to be correct')
    else:
        sim = [1-(textdistance.Jaccard(qval=2).distance(v,input_word)) for v in word_freq.keys()]
        df = pd.DataFrame.from_dict(probs, orient='index').reset_index()
        df = df.rename(columns={'index':'Word', 0:'Prob'})
        df['Similarity'] = sim
        output = df.sort_values(['Similarity', 'Prob'], ascending=False).head()
        return(output)

# %%
word_counts = Counter(words)
print(word_counts["love"])
# Out:
# 55

# %%
total_word_count = float(sum(word_counts.values()))
word_probas = {word: word_counts[word] / total_word_count for word in word_counts.keys()}

# %%
print(word_probas["love"])
# Out:
# 0.00010670991975414035

# %%
def split(word):
  return [(word[:i], word[i:]) for i in range(len(word) + 1)]

# %%
print(split("bread"))
# Out:
# [('', 'bread'), ('b', 'read'), ('br', 'ead'), ('bre', 'ad'), ('brea', 'd'), ('bread', '')]

# %%
def delete(word):
  return [l + r[1:] for l,r in split(word) if r]

# %%
print(delete("bread"))
# Out:
# ['read', 'bead', 'brad', 'bred', 'brea']

# %%
def swap(word):
  return [l + r[1] + r[0] + r[2:] for l, r in split(word) if len(r)>1]

# %%
print(swap("bread"))
# Out:
# ['rbead', 'berad', 'braed', 'breda']

# %%
string.ascii_lowercase
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
def replace(word):
  letters = string.ascii_lowercase
  return [l + c + r[1:] for l, r in split(word) if r for c in letters]

# %%
print(replace("bread"))
# Out:
# ['aread', 'bread', 'cread', 'dread', 'eread', 'fread', 'gread', 'hread', 'iread', 'jread', 'kread', 'lread', 'mread', 'nread', 'oread', 'pread', 'qread', 'rread', 'sread', 'tread', 'uread', 'vread', 'wread', 'xread', 'yread', 'zread', 'baead', 'bbead', 'bcead', 'bdead', 'beead', 'bfead', 'bgead', 'bhead', 'biead', 'bjead', 'bkead', 'blead', 'bmead', 'bnead', 'boead', 'bpead', 'bqead', 'bread', 'bsead', 'btead', 'buead', 'bvead', 'bwead', 'bxead', 'byead', 'bzead', 'braad', 'brbad', 'brcad', 'brdad', 'bread', 'brfad', 'brgad', 'brhad', 'briad', 'brjad', 'brkad', 'brlad', 'brmad', 'brnad', 'broad', 'brpad', 'brqad', 'brrad', 'brsad', 'brtad', 'bruad', 'brvad', 'brwad', 'brxad', 'bryad', 'brzad', 'bread', 'brebd', 'brecd', 'bredd', 'breed', 'brefd', 'bregd', 'brehd', 'breid', 'brejd', 'brekd', 'breld', 'bremd', 'brend', 'breod', 'brepd', 'breqd', 'brerd', 'bresd', 'bretd', 'breud', 'brevd', 'brewd', 'brexd', 'breyd', 'brezd', 'breaa', 'breab', 'breac', 'bread', 'breae', 'breaf', 'breag', 'breah', 'breai', 'breaj', 'break', 'breal', 'bream', 'brean', 'breao', 'breap', 'breaq', 'brear', 'breas', 'breat', 'breau', 'breav', 'breaw', 'breax', 'breay', 'breaz']

# %%
def insert(word):
  letters = string.ascii_lowercase
  return [l + c + r for l, r in split(word) for c in letters]

# %%
print(insert("bread"))
# Out:
# ['abread', 'bbread', 'cbread', 'dbread', 'ebread', 'fbread', 'gbread', 'hbread', 'ibread', 'jbread', 'kbread', 'lbread', 'mbread', 'nbread', 'obread', 'pbread', 'qbread', 'rbread', 'sbread', 'tbread', 'ubread', 'vbread', 'wbread', 'xbread', 'ybread', 'zbread', 'baread', 'bbread', 'bcread', 'bdread', 'beread', 'bfread', 'bgread', 'bhread', 'biread', 'bjread', 'bkread', 'blread', 'bmread', 'bnread', 'boread', 'bpread', 'bqread', 'brread', 'bsread', 'btread', 'buread', 'bvread', 'bwread', 'bxread', 'byread', 'bzread', 'braead', 'brbead', 'brcead', 'brdead', 'breead', 'brfead', 'brgead', 'brhead', 'briead', 'brjead', 'brkead', 'brlead', 'brmead', 'brnead', 'broead', 'brpead', 'brqead', 'brread', 'brsead', 'brtead', 'bruead', 'brvead', 'brwead', 'brxead', 'bryead', 'brzead', 'breaad', 'brebad', 'brecad', 'bredad', 'breead', 'brefad', 'bregad', 'brehad', 'breiad', 'brejad', 'brekad', 'brelad', 'bremad', 'brenad', 'breoad', 'brepad', 'breqad', 'brerad', 'bresad', 'bretad', 'breuad', 'brevad', 'brewad', 'brexad', 'breyad', 'brezad', 'breaad', 'breabd', 'breacd', 'breadd', 'breaed', 'breafd', 'breagd', 'breahd', 'breaid', 'breajd', 'breakd', 'breald', 'breamd', 'breand', 'breaod', 'breapd', 'breaqd', 'breard', 'breasd', 'breatd', 'breaud', 'breavd', 'breawd', 'breaxd', 'breayd', 'breazd', 'breada', 'breadb', 'breadc', 'breadd', 'breade', 'breadf', 'breadg', 'breadh', 'breadi', 'breadj', 'breadk', 'breadl', 'breadm', 'breadn', 'breado', 'breadp', 'breadq', 'breadr', 'breads', 'breadt', 'breadu', 'breadv', 'breadw', 'breadx', 'bready', 'breadz']

# %%
def edit1(word):
  return set(delete(word) + swap(word) + replace(word) + insert(word))

# %%
print(edit1("bread"))
# Out:
# {'breadq', 'brkead', 'vbread', 'xbread', 'bgread', 'breado', 'beead', 'read', 'breadv', 'brkad', 'bnead', 'breqad', 'brecd', 'breabd', 'kread', 'baead', 'bdead', 'bhead', 'breaud', 'breay', 'abread', 'broad', 'brevad', 'brexad', 'breaid', 'brad', 'bjread', 'brpad', 'uread', 'breai', 'jread', 'breasd', 'broead', 'breatd', 'brhead', 'breaq', 'breadu', 'berad', 'brvad', 'brekad', 'gread', 'breid', 'wbread', 'mbread', 'breand', 'brcad', 'ubread', 'breadi', 'brecad', 'brtad', 'rbead', 'pbread', 'brenad', 'brear', 'brnad', 'breadh', 'breawd', 'brfad', 'breoad', 'hbread', 'bcead', 'lbread', 'bready', 'breavd', 'breagd', 'brtead', 'brgad', 'bzead', 'brzad', 'zbread', 'brfead', 'btead', 'brsad', 'braed', 'breaj', 'dread', 'breapd', 'qread', 'sread', 'bxead', 'bsread', 'breadt', 'kbread', 'breadp', 'breadz', 'byead', 'breuad', 'brerad', 'breaf', 'brexd', 'dbread', 'brlead', 'bqead', 'nbread', 'breadc', 'brejd', 'bregad', 'breyad', 'breada', 'brepad', 'bead', 'bvead', 'vread', 'brdead', 'breaad', 'breard', 'brekd', 'breld', 'bzread', 'biread', 'yread', 'brbead', 'brmead', 'breal', 'bjead', 'brezd', 'breazd', 'fread', 'breadm', 'xread', 'breed', 'ybread', 'brjad', 'brbad', 'breaqd', 'bream', 'brehad', 'pread', 'breaa', 'breaz', 'breead', 'bretad', 'obread', 'bmead', 'breadb', 'breadk', 'blread', 'bnread', 'breab', 'brrad', 'bryad', 'rread', 'bbead', 'qbread', 'brpead', 'brewad', 'cread', 'breakd', 'bkead', 'zread', 'brefd', 'breao', 'breat', 'breax', 'fbread', 'bremad', 'brewd', 'breau', 'bwead', 'ibread', 'brqead', 'brwead', 'bredad', 'brebd', 'bqread', 'brnead', 'brxead', 'brdad', 'bpread', 'bvread', 'bwread', 'briead', 'bpead', 'aread', 'eread', 'bgead', 'break', 'breac', 'breav', 'oread', 'breajd', 'bremd', 'breadj', 'lread', 'brehd', 'ebread', 'bred', 'briad', 'boead', 'brread', 'bretd', 'breod', 'brqad', 'tread', 'byread', 'brzead', 'brjead', 'brelad', 'bruead', 'breacd', 'breadg', 'wread', 'brerd', 'rbread', 'baread', 'braead', 'breyd', 'iread', 'breald', 'breaxd', 'hread', 'bruad', 'breadx', 'btread', 'breafd', 'breaed', 'bsead', 'breadd', 'bresad', 'cbread', 'bhread', 'breadl', 'biead', 'brmad', 'brezad', 'brean', 'breadf', 'brevd', 'tbread', 'bcread', 'brepd', 'bryead', 'buead', 'breas', 'bfead', 'breae', 'breayd', 'bxread', 'brefad', 'breah', 'jbread', 'bdread', 'breadr', 'brvead', 'beread', 'breiad', 'breqd', 'gbread', 'brwad', 'bkread', 'breadn', 'breads', 'brlad', 'breaod', 'mread', 'brebad', 'breahd', 'boread', 'buread', 'brhad', 'sbread', 'bbread', 'bregd', 'brejad', 'bread', 'brxad', 'brea', 'nread', 'brend', 'bmread', 'breud', 'breadw', 'brcead', 'braad', 'breaw', 'breap', 'breamd', 'blead', 'brsead', 'breade', 'bresd', 'brgead', 'breag', 'breda', 'bredd', 'bfread'}

# %%
def edit2(word):
  return set(e2 for e1 in edit1(word) for e2 in edit1(e1))

# %%
print(edit2("bread"))
# Out:
# {'brweadm', 'brynad', 'bysad', 'tbrtad', 'byeaz', 'brepr', 'pbrlad', 'bkretd', 'tbreald', 'bmpad', 'bireakd', 'breawid', 'bwaead', 'bnreal', 'vreafd', 'bseadz', 'breywad', 'breandm', 'brheadc', 'ireaj', 'blewad', 'brealrd', 'brceat', 'bjeafd', 'breadzv', 'tbreasd', 'paread', 'blrmead', 'brfsd', 'breqt', 'bteau', 'bbeamd', 'bwecad', 'gbrzad', 'breoadw', 'burpead', 'xbredad', 'rbrkad', 'bresdt', 'brmeagd', 'breafn', 'xbresad', 'ybreavd', 'brveed', 'efread', 'abrread', 'breaii', 'trad', 'broehad', 'ureah', 'onbread', 'breasyd', 'rreag', 'bredgd', 'brkfad', 'jreakd', 'bjyread', 'bkerd', 'brpeaz', 'brefald', 'brjeaa', 'rbrelad', 'brewadw', 'qbreadg', 'brewdr', 'brseadd', 'bvreyd', 'breadjo', 'brraad', 'brewe', 'brads', 'ybrnad', 'brfud', 'btsread', 'berrd', 'ibreahd', 'bwdad', 'brewde', 'bhrenad', 'qblead', 'breadey', 'brearpd', 'bhreadp', 'breadea', 'bxrbead', 'bfreafd', 'bwbead', 'rbeakd', 'sbaread', 'pbream', 'tbreadb', 'boreab', 'brmeand', 'bfrgad', 'bteada', 'wreadv', 'ybrkead', 'mreard', 'buevd', 'bceao', 'bdemd', 'vreado', 'kbrexad', 'msbread', 'breyhd', 'bhbad', 'qrerd', 'brieald', 'bkreavd', 'oqread', 'brevar', 'bgeaid', 'obreard', 'dzread', 'lreaa', 'bereaad', 'vrmad', 'brezvad', 'baeaw', 'brieadv', 'brytad', 'bcemad', 'brfda', 'qreadd', 'vbfread', 'jrfad', 'brweax', 'ebrxad', 'bkrdead', 'ebregd', 'brekm', 'bveazd', 'vred', 'breakdv', 'lroead', 'btreyad', 'breeau', 'mpbread', 'brkeqd', 'brceasd', 'byeid', 'brjadd', 'fbreade', 'bmreac', 'mbmread', 'bnreadq', 'vbrjad', 'nbrekad', 'bzelad', 'gbrekd', 'breayfd', 'baehd', 'brpeadc', 'brhecd', 'bmaad', 'brraid', 'hgead', 'ibretad', 'brwxd', 'brnpad', 'byevd', 'bneag', 'brtvd', 'brnebd', 'brbyad', 'lrfead', 'mnread', 'brepvd', 'brskad', 'gbrenad', 'qbreac', 'brqwd', 'breto', 'rbreae', 'brecat', 'btwead', 'hbreag', 'berad', 'brqeadh', 'bbeed', 'ldead', 'cbnead', 'brbeadv', 'breakdq', 'boreavd', 'ereasd', 'breaysd', 'butad', 'brevdx', 'breatq', 'bteapd', 'bhrebd', 'brepadv', 'brnetd', 'tbreawd', 'xbrezd', 'bjrpad', 'breafsd', 'freacd', 'rbvead', 'brevadi', 'beeatd', 'bnreag', 'bgrfead', 'brntead', 'bpaed', 'brxemd', 'breador', 'trvead', 'broadl', 'broadw', 'breraj', 'breawf', 'vbreaod', 'bxreid', 'brekt', 'btreac', 'bdrexd', 'ybreap', 'breaym', 'brepdi', 'rbeao', 'brlread', 'avread', 'brwekad', 'bcreahd', 'lbrea', 'brreid', 'birear', 'dboead', 'mreahd', 'brer', 'ybroad', 'ibrefad', 'nreaad', 'bjexad', 'freead', 'breajod', 'bqregd', 'bwvread', 'oreadk', 'ubrsead', 'bteand', 'aaread', 'breyapd', 'bgeavd', 'broaa', 'bbreda', 'breadnz', 'rekad', 'brxdead', 'brwaad', 'faread', 'obroad', 'bmaed', 'kreqad', 'bieahd', 'brladf', 'brueae', 'breasda', 'bcreiad', 'brexadm', 'jbreai', 'bvkead', 'breafb', 'rraed', 'bera', 'bneadt', 'otread', 'saead', 'mbrnad', 'brhadg', 'brwadw', 'brepao', 'brleaq', 'bfreadr', 'bzeadn', 'braeard', 'bjrvead', 'bspead', 'mrtad', 'rreadv', 'vbfead', 'bkeaud', 'pbraed', 'rbeaed', 'briepd', 'urqad', 'bmreas', 'breadqq', 'bweadm', 'bhtead', 'brekae', 'urvead', 'bhecd', 'breanzd', 'breewad', 'bdreasd', 'jbregad', 'brjegd', 'bjred', 'breied', 'brfan', 'vcread', 'rbreav', 'ddbread', 'mbreaz', 'berxead', 'brbeatd', 'bdsread', 'barepad', 'bpetad', 'breaadv', 'lbreah', 'lbream', 'breavgd', 'qbreadh', 'sbrevad', 'brefdp', 'mrepd', 'xaead', 'borzad', 'bqvad', 'wjead', 'rbemd', 'bretadx', 'ybreqd', 'breavtd', 'yreay', 'nbrread', 'brpeau', 'brewpad', 'irqead', 'bhriad', 'brvaqd', 'brrayd', 'breayc', 'brfewd', 'benrad', 'brpeadm', 'oreasd', 'brsaod', 'breaxdu', 'bremdh', 'brjeoad', 'vbreax', 'brecdn', 'breadfz', 'wryad', 'bdreaw', 'breamc', 'brfeaz', 'reud', 'erpad', 'wbrehad', 'brtfead', 'bkmread', 'brmeaod', 'lreao', 'sbrqead', 'obriead', 'bremadl', 'xrbead', 'abrlead', 'brdadj', 'brzay', 'xreavd', 'ptead', 'bzeaj', 'bireajd', 'obroead', 'becread', 'brecrad', 'brqady', 'breazgd', 'brnao', 'cruad', 'bvnread', 'ibrjead', 'fmread', 'rbreaa', 'brehvad', 'brueabd', 'rreadq', 'brecdp', 'sreaw', 'bprefad', 'brzzad', 'brvar', 'iqead', 'cbwead', 'bbeado', 'bxreadt', 'bprbad', 'vreuad' ...

# %%
def correct_spelling(word, vocabulary, word_probabilities):
  if word in vocabulary:
    print(f"{word} is already correctly spelt")
    return 

  suggestions = edit1(word) or edit2(word) or [word]
  best_guesses = [w for w in suggestions if w in vocabulary]
  return [(w, word_probabilities[w]) for w in best_guesses]

# %%
word = "famile"
corrections = correct_spelling(word, vocabs, word_probas)

if corrections:
  print(corrections)
  probs = np.array([c[1] for c in corrections])
  best_ix = np.argmax(probs)
  correct = corrections[best_ix][0]
  print(f"{correct} is suggested for {word}")
# Out:
# [('facile', 1.940180359166188e-06), ('camile', 1.940180359166188e-06), ('famine', 5.820541077498564e-06), ('famble', 3.880360718332376e-06), ('family', 9.70090179583094e-06), ('famille', 1.940180359166188e-06)]
# family is suggested for famile

# %%
class SpellChecker(object):

  def __init__(self, corpus_file_path):
    with open(corpus_file_path, "r") as file:
      lines = file.readlines()
      words = []
      for line in lines:
        words += re.findall(r'\w+', line.lower())

    self.vocabs = set(words)
    self.word_counts = Counter(words)
    total_words = float(sum(self.word_counts.values()))
    self.word_probas = {word: self.word_counts[word] / total_words for word in self.vocabs}

  def _level_one_edits(self, word):
    letters = string.ascii_lowercase
    splits = [(word[:i], word[i:]) for i in range(len(word) + 1)]
    deletes = [l + r[1:] for l,r in splits if r]
    swaps = [l + r[1] + r[0] + r[2:] for l, r in splits if len(r)>1]
    replaces = [l + c + r[1:] for l, r in splits if r for c in letters]
    inserts = [l + c + r for l, r in splits for c in letters] 

    return set(deletes + swaps + replaces + inserts)

  def _level_two_edits(self, word):
    return set(e2 for e1 in self._level_one_edits(word) for e2 in self._level_one_edits(e1))

  def check(self, word):
    candidates = self._level_one_edits(word) or self._level_two_edits(word) or [word]
    valid_candidates = [w for w in candidates if w in self.vocabs]
    return sorted([(c, self.word_probas[c]) for c in valid_candidates], key=lambda tup: tup[1], reverse=True)

# %%
checker = SpellChecker("words.txt")

# %%
checker.check("sentense")
# Out:
# [('sentence', 1.940180359166188e-06)]

# %%
checker.check("")
# Out:
# [('frail', 5.820541077498564e-06),
#  ('frails', 1.940180359166188e-06),
#  ('fraple', 1.940180359166188e-06),
#  ('fraise', 1.940180359166188e-06),
#  ('fragile', 1.940180359166188e-06),
#  ('fraile', 1.940180359166188e-06),
#  ('frailes', 1.940180359166188e-06),
#  ('frailer', 1.940180359166188e-06)]
